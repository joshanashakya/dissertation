# %%
import io
import tokenize
inp = 'import math \n def findRadiusOfcircumcircle(l,b): \n \t if(l<0 or b<0): \n \t \t return-1; \n radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n return radius; \n l=4; \n b=3; \n print(findRadiusOfcircumcircle(l,b)); \n'
# inp = 'print(+21.3e-5*-.1234/81.7)'
for token in tokenize.generate_tokens(io.StringIO(inp).readline):
    print(token)
# Out:
# TokenInfo(type=1 (NAME), string='import', start=(1, 0), end=(1, 6), line='import math \n')
# TokenInfo(type=1 (NAME), string='math', start=(1, 7), end=(1, 11), line='import math \n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(1, 12), end=(1, 13), line='import math \n')
# TokenInfo(type=5 (INDENT), string=' ', start=(2, 0), end=(2, 1), line=' def findRadiusOfcircumcircle(l,b): \n')
# TokenInfo(type=1 (NAME), string='def', start=(2, 1), end=(2, 4), line=' def findRadiusOfcircumcircle(l,b): \n')
# TokenInfo(type=1 (NAME), string='findRadiusOfcircumcircle', start=(2, 5), end=(2, 29), line=' def findRadiusOfcircumcircle(l,b): \n')
# TokenInfo(type=54 (OP), string='(', start=(2, 29), end=(2, 30), line=' def findRadiusOfcircumcircle(l,b): \n')
# TokenInfo(type=1 (NAME), string='l', start=(2, 30), end=(2, 31), line=' def findRadiusOfcircumcircle(l,b): \n')
# TokenInfo(type=54 (OP), string=',', start=(2, 31), end=(2, 32), line=' def findRadiusOfcircumcircle(l,b): \n')
# TokenInfo(type=1 (NAME), string='b', start=(2, 32), end=(2, 33), line=' def findRadiusOfcircumcircle(l,b): \n')
# TokenInfo(type=54 (OP), string=')', start=(2, 33), end=(2, 34), line=' def findRadiusOfcircumcircle(l,b): \n')
# TokenInfo(type=54 (OP), string=':', start=(2, 34), end=(2, 35), line=' def findRadiusOfcircumcircle(l,b): \n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(2, 36), end=(2, 37), line=' def findRadiusOfcircumcircle(l,b): \n')
# TokenInfo(type=5 (INDENT), string=' \t ', start=(3, 0), end=(3, 3), line=' \t if(l<0 or b<0): \n')
# TokenInfo(type=1 (NAME), string='if', start=(3, 3), end=(3, 5), line=' \t if(l<0 or b<0): \n')
# TokenInfo(type=54 (OP), string='(', start=(3, 5), end=(3, 6), line=' \t if(l<0 or b<0): \n')
# TokenInfo(type=1 (NAME), string='l', start=(3, 6), end=(3, 7), line=' \t if(l<0 or b<0): \n')
# TokenInfo(type=54 (OP), string='<', start=(3, 7), end=(3, 8), line=' \t if(l<0 or b<0): \n')
# TokenInfo(type=2 (NUMBER), string='0', start=(3, 8), end=(3, 9), line=' \t if(l<0 or b<0): \n')
# TokenInfo(type=1 (NAME), string='or', start=(3, 10), end=(3, 12), line=' \t if(l<0 or b<0): \n')
# TokenInfo(type=1 (NAME), string='b', start=(3, 13), end=(3, 14), line=' \t if(l<0 or b<0): \n')
# TokenInfo(type=54 (OP), string='<', start=(3, 14), end=(3, 15), line=' \t if(l<0 or b<0): \n')
# TokenInfo(type=2 (NUMBER), string='0', start=(3, 15), end=(3, 16), line=' \t if(l<0 or b<0): \n')
# TokenInfo(type=54 (OP), string=')', start=(3, 16), end=(3, 17), line=' \t if(l<0 or b<0): \n')
# TokenInfo(type=54 (OP), string=':', start=(3, 17), end=(3, 18), line=' \t if(l<0 or b<0): \n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(3, 19), end=(3, 20), line=' \t if(l<0 or b<0): \n')
# TokenInfo(type=5 (INDENT), string=' \t \t ', start=(4, 0), end=(4, 5), line=' \t \t return-1; \n')
# TokenInfo(type=1 (NAME), string='return', start=(4, 5), end=(4, 11), line=' \t \t return-1; \n')
# TokenInfo(type=54 (OP), string='-', start=(4, 11), end=(4, 12), line=' \t \t return-1; \n')
# TokenInfo(type=2 (NUMBER), string='1', start=(4, 12), end=(4, 13), line=' \t \t return-1; \n')
# TokenInfo(type=54 (OP), string=';', start=(4, 13), end=(4, 14), line=' \t \t return-1; \n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(4, 15), end=(4, 16), line=' \t \t return-1; \n')
# TokenInfo(type=6 (DEDENT), string='', start=(5, 1), end=(5, 1), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=6 (DEDENT), string='', start=(5, 1), end=(5, 1), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=1 (NAME), string='radius', start=(5, 1), end=(5, 7), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=54 (OP), string='=', start=(5, 7), end=(5, 8), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=54 (OP), string='(', start=(5, 8), end=(5, 9), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=1 (NAME), string='math', start=(5, 9), end=(5, 13), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=54 (OP), string='.', start=(5, 13), end=(5, 14), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=1 (NAME), string='sqrt', start=(5, 14), end=(5, 18), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=54 (OP), string='(', start=(5, 18), end=(5, 19), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=1 (NAME), string='pow', start=(5, 19), end=(5, 22), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=54 (OP), string='(', start=(5, 22), end=(5, 23), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=1 (NAME), string='l', start=(5, 23), end=(5, 24), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=54 (OP), string=',', start=(5, 24), end=(5, 25), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=2 (NUMBER), string='2', start=(5, 25), end=(5, 26), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=54 (OP), string=')', start=(5, 26), end=(5, 27), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=54 (OP), string='+', start=(5, 27), end=(5, 28), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=1 (NAME), string='pow', start=(5, 28), end=(5, 31), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=54 (OP), string='(', start=(5, 31), end=(5, 32), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=1 (NAME), string='b', start=(5, 32), end=(5, 33), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=54 (OP), string=',', start=(5, 33), end=(5, 34), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=2 (NUMBER), string='2', start=(5, 34), end=(5, 35), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=54 (OP), string=')', start=(5, 35), end=(5, 36), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=54 (OP), string=')', start=(5, 36), end=(5, 37), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=54 (OP), string='/', start=(5, 37), end=(5, 38), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=2 (NUMBER), string='2', start=(5, 38), end=(5, 39), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=54 (OP), string=')', start=(5, 39), end=(5, 40), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=54 (OP), string=';', start=(5, 40), end=(5, 41), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(5, 42), end=(5, 43), line=' radius=(math.sqrt(pow(l,2)+pow(b,2))/2); \n')
# TokenInfo(type=1 (NAME), string='return', start=(6, 1), end=(6, 7), line=' return radius; \n')
# TokenInfo(type=1 (NAME), string='radius', start=(6, 8), end=(6, 14), line=' return radius; \n')
# TokenInfo(type=54 (OP), string=';', start=(6, 14), end=(6, 15), line=' return radius; \n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(6, 16), end=(6, 17), line=' return radius; \n')
# TokenInfo(type=1 (NAME), string='l', start=(7, 1), end=(7, 2), line=' l=4; \n')
# TokenInfo(type=54 (OP), string='=', start=(7, 2), end=(7, 3), line=' l=4; \n')
# TokenInfo(type=2 (NUMBER), string='4', start=(7, 3), end=(7, 4), line=' l=4; \n')
# TokenInfo(type=54 (OP), string=';', start=(7, 4), end=(7, 5), line=' l=4; \n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(7, 6), end=(7, 7), line=' l=4; \n')
# TokenInfo(type=1 (NAME), string='b', start=(8, 1), end=(8, 2), line=' b=3; \n')
# TokenInfo(type=54 (OP), string='=', start=(8, 2), end=(8, 3), line=' b=3; \n')
# TokenInfo(type=2 (NUMBER), string='3', start=(8, 3), end=(8, 4), line=' b=3; \n')
# TokenInfo(type=54 (OP), string=';', start=(8, 4), end=(8, 5), line=' b=3; \n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(8, 6), end=(8, 7), line=' b=3; \n')
# TokenInfo(type=1 (NAME), string='print', start=(9, 1), end=(9, 6), line=' print(findRadiusOfcircumcircle(l,b)); \n')
# TokenInfo(type=54 (OP), string='(', start=(9, 6), end=(9, 7), line=' print(findRadiusOfcircumcircle(l,b)); \n')
# TokenInfo(type=1 (NAME), string='findRadiusOfcircumcircle', start=(9, 7), end=(9, 31), line=' print(findRadiusOfcircumcircle(l,b)); \n')
# TokenInfo(type=54 (OP), string='(', start=(9, 31), end=(9, 32), line=' print(findRadiusOfcircumcircle(l,b)); \n')
# TokenInfo(type=1 (NAME), string='l', start=(9, 32), end=(9, 33), line=' print(findRadiusOfcircumcircle(l,b)); \n')
# TokenInfo(type=54 (OP), string=',', start=(9, 33), end=(9, 34), line=' print(findRadiusOfcircumcircle(l,b)); \n')
# TokenInfo(type=1 (NAME), string='b', start=(9, 34), end=(9, 35), line=' print(findRadiusOfcircumcircle(l,b)); \n')
# TokenInfo(type=54 (OP), string=')', start=(9, 35), end=(9, 36), line=' print(findRadiusOfcircumcircle(l,b)); \n')
# TokenInfo(type=54 (OP), string=')', start=(9, 36), end=(9, 37), line=' print(findRadiusOfcircumcircle(l,b)); \n')
# TokenInfo(type=54 (OP), string=';', start=(9, 37), end=(9, 38), line=' print(findRadiusOfcircumcircle(l,b)); \n')
# TokenInfo(type=4 (NEWLINE), string='\n', start=(9, 39), end=(9, 40), line=' print(findRadiusOfcircumcircle(l,b)); \n')
# TokenInfo(type=6 (DEDENT), string='', start=(10, 0), end=(10, 0), line='')
# TokenInfo(type=0 (ENDMARKER), string='', start=(10, 0), end=(10, 0), line='')
